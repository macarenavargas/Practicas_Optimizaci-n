# %% [markdown]
# # Proyecto final
#
# Cristina Hernández, Beatriz Jimenez, Macarena Vargas, Guillermo Ruiz

# %%
import pyomo.environ as pe
import pyomo.opt as po
from pyomo.environ import NonNegativeReals, Binary

# %% [markdown]
# #### Create the model

# %%
model = pe.ConcreteModel()

# %% [markdown]
# #### Sets
# ### 1. Conjuntos (Sets)
# El modelo se define sobre los siguientes conjuntos que representan las dimensiones del problema:
#
# * $D$: Conjunto de días de la semana, $D = \{\text{Lunes, Martes, ..., Domingo}\}$.
# * $P$: Periodos del día, $P = \{\text{Mañana, Tarde}\}$.
# * $H_p$: Bloques horarios disponibles en el periodo $p \in P$, donde $H_p = \{1, 2, 3, 4, 5\}$.
# * $A$: Tipos de actividades a organizar, $A = \{\text{Yoga, Reunión, Clase Niños, Taller}\}$.
# * $S$: Supervisores disponibles para el local, $S = \{\text{Sup1, Sup2}\}$.
# * $\Omega$: Espacio temporal completo (Día, Periodo, Hora), definido como el producto cartesiano:
#     $$\Omega = \{(d, p, h) : d \in D, p \in P, h \in H_p\}$$

# %%
# 1. Listas de datos básicos
DAYS = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
PERIODS = ["Morning", "Afternoon"]
ACTIVITIES = ["Yoga", "CommunityMeeting", "KidsClass", "CraftsWorkshop"]
SUPERVISORS = ["Supervisor1", "Supervisor2"]

# Bloques horarios por periodo 
HM = [1, 2, 3, 4, 5]  
HA = [1, 2, 3, 4, 5]  

# 2. Creación de Sets en Pyomo
# Estos sets permiten al modelo iterar sobre los días, actividades y personas
model.d = pe.Set(initialize=DAYS, doc='Días de la semana')
model.p = pe.Set(initialize=PERIODS, doc='Periodos (Mañana/Tarde)')
model.a = pe.Set(initialize=ACTIVITIES, doc='Tipos de actividades')
model.s = pe.Set(initialize=SUPERVISORS, doc='Personal disponible')

# 3. Sets Horarios Indexados
# Definimos las horas que pertenecen a cada bloque
model.Hm = pe.Set(initialize=HM)
model.Ha = pe.Set(initialize=HA)

# Función para asignar automáticamente los bloques de horas según el periodo (P)
def H_init(m, p):
    return HM if p == "Morning" else HA

# H[p] es un Set indexado: model.H['Morning'] contendrá [1,2,3,4,5]
model.H = pe.Set(model.p, initialize=H_init, doc='Horas disponibles por periodo')  

# 4. Set Espacial Completo (Producto Cartesiano)
# dph crea el "calendario vacío" combinando (Día, Periodo, Hora)
# Esto genera el espacio de decisión donde se ubicarán las actividades.
model.dph = pe.Set(
    dimen=3,
    initialize=[(d, p, h) for d in DAYS for p in PERIODS for h in (HM if p=="Morning" else HA)],
    doc='Espacio temporal completo del modelo'
)

# %% [markdown]
# #### Parameters
#
#
# * $RA_{d,p,h}$: Disponibilidad del local en el día $d$, periodo $p$ y hora $h$ ($1$ si disponible, $0$ si no).
# * $S_{min,a} / S_{max,a}$: Número mínimo y máximo de sesiones semanales permitidas para la actividad $a$.
# * $Dur_a$: Duración en bloques horarios consecutivos de la actividad $a$.
# * $NS_a$: Requerimiento de supervisor para la actividad $a$ (binario).
# * $SA_{s,d,p,h}$: Disponibilidad del supervisor $s$ en el momento $(d,p,h)$.
# * $Cap$: Capacidad máxima de asistentes.
# * $D_{a,d,p,h}$: Demanda estimada de vecinos para la actividad $a$ en el horario $(d,p,h)$.

# %%
# 1. Disponibilidad de la sala (room availability)
# Inicializamos el local como disponible para todos los bloques del calendario
room_avail = {(d,p,h): 1 for d in DAYS for p in PERIODS for h in (HM if p=="Morning" else HA)}
model.room_avail = pe.Param(
    model.dph,
    initialize=lambda m,d,p,h: room_avail[(d,p,h)],
    within=pe.Binary
)

# 2. frecuencia y duracion

# Mínimo de sesiones semanales por actividad 
min_sessions = {a: 1 for a in ACTIVITIES} # inicializamos minimo 1 sesión por semana

model.min_sessions = pe.Param(
    model.a,
    initialize=lambda m,a: min_sessions[a],
    within=pe.NonNegativeIntegers
)

# Máximo de sesiones semanales
max_sessions = {a: 5 for a in ACTIVITIES} # inicializacom a máximo 5 sesiones por semana
model.max_sessions = pe.Param(
    model.a,
    initialize=lambda m,a: max_sessions[a],
    within=pe.NonNegativeIntegers
)


# Duración de cada actividad en bloques horarios (que tiene que ir consecutivos)
dur = {
    "Yoga": 2,
    "CommunityMeeting": 1,
    "KidsClass": 2,
    "CraftsWorkshop": 1
}

model.dur = pe.Param(
    model.a,
    initialize=lambda m, a: dur[a],
    within=pe.PositiveIntegers
)

# 3. Supervisión y Personal
# Indica si la actividad requiere presencia de personal (1=Sí, 0=No)

needs_sup = {a: 1 for a in ACTIVITIES} # inicializamos a que todas las actividades requieran supervisor
model.needs_sup = pe.Param(
    model.a,
    initialize=lambda m,a: needs_sup[a],
    within=pe.Binary
)

# Disponibilidad de los supervisores
# Simulamos que los supervisores descansan el domingo por la tarde
sup_avail = {
    (s, d, p, h): 0 if (d == "Sunday" and p == "Afternoon") else 1
    for s in SUPERVISORS
    for d, p, h in model.dph
}
model.sup_avail = pe.Param(
    model.s, model.dph,
    initialize=lambda m, s, d, p, h: sup_avail[(s, d, p, h)],
    within=pe.Binary,
    default=0
)

# 4. Capacidad y Demanda Estimada
# Aforo máximo del local
CAPACITY_VALUE = 25  
model.capacity = pe.Param(
    initialize=CAPACITY_VALUE,
    within=pe.PositiveIntegers
)


# Demanda esperada según el tipo de actividad 
demand = {
    (a, d, p, h): 15 if a == "Yoga" 
    else 20 if a == "KidsClass" 
    else 10
    for a in ACTIVITIES
    for d, p, h in model.dph
}

model.demand = pe.Param(
    model.a, model.dph,
    initialize=lambda m,a,d,p,h: demand[(a,d,p,h)],
    within=pe.NonNegativeIntegers
)

# %% [markdown]
# #### Variables
# * $X_{a,d,p,h} \in \{0, 1\}$: Binary variable that equals 1 if activity $a$ starts on day $d$, period $p$, and time slot $h$; 0 otherwise.
# * $n_{a,d,p,h} \in \mathbb{Z}^+$: Integer variable representing the number of attendees for activity $a$ starting at $(d,p,h)$.
# * $y_{a,d,p,h,s} \in \{0, 1\}$: Binary variable that equals 1 if supervisor $s$ is assigned to activity $a$ starting at $(d,p,h)$; 0 otherwise.
# * $R_{a,d,p,h} \in \{0, 1\}$: Binary "Running" variable that equals 1 if activity $a$ is active (occupying the room) at $(d,p,h)$, regardless of when it started.
# * $Z_{min} \in \mathbb{Z}^+$: Auxiliary variable used for multi-criteria analysis, representing the minimum number of attendees across all scheduled sessions.

# %%
# binary (1 if activity a starts on day d at period p time h else 0)
model.X = pe.Var(model.a, model.dph, within=pe.Binary)

# number of attendees of activity a that starts on day d at period d at time slot h
model.n = pe.Var(model.a, model.dph, within=pe.NonNegativeIntegers)

# binary (1 if supervisor s is assigned to activity a at d,p,h)
model.y = pe.Var(model.a, model.dph, model.s, within=pe.Binary)

# auxiliary variable (minimum number of persons among all sessions)
model.Z = pe.Var(within=pe.NonNegativeIntegers)

# binary (1 if activity a is running on day d at period p time h else 0)
model.R = pe.Var(model.a, model.dph, within=pe.Binary)

# %% [markdown]
# #### Objective Function

# %%
def obj_rule(m):
    return m.Z

model.obj = pe.Objective(rule=obj_rule, sense=pe.maximize)

# second objective function (for max(min))

def total_attendees_rule(m):
    return sum(m.n[a,(d,p,h)] for a in m.a for (d,p,h) in m.dph)

model.obj_total = pe.Objective(rule=total_attendees_rule, sense=pe.maximize)
model.obj_total.deactivate()

# %% [markdown]
# ### Constraints

# %% [markdown]
# #### 1. Valid start time: Only allow an activity to start if the current hour plus the duration doesn't go past the limit.
#
# $$h + Dur_{a} - 1 \leq \max(H_{p}) \quad \forall a \in A, p \in P, h \in H_{p}$$

# %%
# valid start time slots
def valid_start(m, a, p, h):
    return h + pe.value(m.dur[a]) - 1 <= max(m.H[p])

# %% [markdown]
# #### 2. Activity Running Link: This constraint links the start variable $X$ with the state variable $R$. It ensures that if an activity $a$ starts at time $t$, it continues to occupy the room for its entire duration $Dur_a$.
#
# $$R_{a,d,p,h} = \sum_{t \in H_p : t \leq h \leq t + Dur_a - 1} X_{a,d,p,t} \quad \forall a \in A, (d,p,h) \in \Omega$$

# %%
# activity running definition
def running_link_rule(m, a, d, p, h):
    return m.R[a,(d,p,h)] == sum(
        m.X[a,(d,p,t)]
        for t in m.H[p]
        if valid_start(m,a,p,t) and t <= h <= t + pe.value(m.dur[a]) - 1
    )

model.running_link = pe.Constraint(model.a, model.dph, rule=running_link_rule)

# %%
# invalid starts forced to zero
def invalid_start_rule(m, a, d, p, h):
    if valid_start(m,a,p,h):
        return pe.Constraint.Skip
    return m.X[a,(d,p,h)] == 0

model.invalid_start = pe.Constraint(model.a, model.dph, rule=invalid_start_rule)

# %% [markdown]
# * $ \sum_{a \in A} R_{a,d,p,h} \leq RA_{d,p,h} \quad \forall (d,p,h) \in \Omega $

# %%
# room availability
def room_availability_rule(m, d, p, h):
    return sum(m.R[a,(d,p,h)] for a in m.a) <= m.room_avail[d,p,h]

model.room_availability = pe.Constraint(model.dph, rule=room_availability_rule)

# %%
# no overlapping activities
def no_overlap_rule(m, d, p, h):
    return sum(m.R[a,(d,p,h)] for a in m.a) <= 1

model.no_overlap = pe.Constraint(model.dph, rule=no_overlap_rule)

# %%
# supervisor required
def supervisor_required_rule(m, a, d, p, h):
    return sum(m.y[a,(d,p,h),s] for s in m.s) >= m.needs_sup[a] * m.X[a,(d,p,h)]

model.supervisor_required = pe.Constraint(model.a, model.dph, rule=supervisor_required_rule)

# %%
# supervisor availability for full duration
model.sup_avail_full = pe.ConstraintList()

for a in model.a:
    for (d,p,h) in model.dph:
        if not valid_start(model,a,p,h):
            continue
        dur_a = int(pe.value(model.dur[a]))
        for s in model.s:
            for k in range(h, h + dur_a):
                model.sup_avail_full.add(
                    model.y[a,(d,p,h),s] <= model.sup_avail[s,d,p,k]
                )

# %%
# supervisor no overlap
def supervisor_no_overlap_rule(m, s, d, p, h):
    return sum(
        m.y[a,(d,p,t),s]
        for a in m.a
        for t in m.H[p]
        if valid_start(m,a,p,t) and t <= h <= t + pe.value(m.dur[a]) - 1
    ) <= 1

model.supervisor_no_overlap = pe.Constraint(model.s, model.dph, rule=supervisor_no_overlap_rule)

# %%
# capacity constraint
def capacity_rule(m, a, d, p, h):
    return m.n[a,(d,p,h)] <= m.capacity * m.X[a,(d,p,h)]

model.capacity_constraint = pe.Constraint(model.a, model.dph, rule=capacity_rule)

# %%
# demand constraint
def demand_rule(m, a, d, p, h):
    return m.n[a,(d,p,h)] <= m.demand[a,d,p,h] * m.X[a,(d,p,h)]

model.demand_constraint = pe.Constraint(model.a, model.dph, rule=demand_rule)

# %%
# minimum weekly sessions per activity
def min_sessions_rule(m, a):
    return sum(
        m.X[a,(d,p,h)]
        for (d,p,h) in m.dph
        if valid_start(m,a,p,h)
    ) >= m.min_sessions[a]

model.min_sessions_constraint = pe.Constraint(model.a, rule=min_sessions_rule)

# %%
# maximum weekly sessions per activity
def max_sessions_rule(m, a):
    return sum(
        m.X[a,(d,p,h)]
        for (d,p,h) in m.dph
        if valid_start(m,a,p,h)
    ) <= m.max_sessions[a]

model.max_sessions_constraint = pe.Constraint(model.a, rule=max_sessions_rule)

# %%
# z definition
M = CAPACITY_VALUE

def z_rule(m, a, d, p, h):
    return m.Z <= m.n[a,(d,p,h)] + M * (1 - m.X[a,(d,p,h)])

model.z_constraint = pe.Constraint(model.a, model.dph, rule=z_rule)

# %% [markdown]
# #### Solve model

# %%
solver = pe.SolverFactory('gurobi')

#first objective function
results_1 = solver.solve(model, tee=True)

print("===1===")
print("Solver Status:", results_1.solver.status)
print("Termination Condition:", results_1.solver.termination_condition)

z_star = pe.value(model.Z)

# second objetive function

model.obj.deactivate()
model.obj_total.activate()

results_2 = solver.solve(model, tee=True)

print("\n\n===2==")
print("Solver Status:", results_2.solver.status)
print("Termination Condition:", results_2.solver.termination_condition)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2707518
# Academic license - for non-commercial use only - expires 2026-09-11
# Read LP format model from file C:\Users\Guill\AppData\Local\Temp\tmpky3pcy51.pyomo.lp
# Reading time = 0.10 seconds
# x1: 2444 rows, 1401 columns, 5992 nonzeros
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2444 rows, 1401 columns and 5992 nonzeros
# Model fingerprint: 0x3b64c3cc
# Variable types: 0 continuous, 1401 integer (1120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 1942 rows and 698 columns
# Presolve time: 0.09s
# ...

# %%
## first objective function
print("First objective function")
print("Z = optimum minimum =", z_star)
total_1 = sum(pe.value(model.n[a,(d,p,h)]) for a in model.a for (d,p,h) in model.dph)
print("Total people assisting  =", total_1)

## second objective function
print("\nSecond objective function")
print("Z =", pe.value(model.Z))
print("Total people asisting =", sum(pe.value(model.n[a,(d,p,h)]) for a in model.a for (d,p,h) in model.dph))
# Out:
# First objective function
# Z = optimum minimum = 10.0
# Total people assisting  = 275.0
#
# Second objective function
# Z = -0.0
# Total people asisting = 275.0
