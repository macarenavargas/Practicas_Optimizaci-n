# %% [markdown]
# # Proyecto final: Neighborhood asociation
#
# Cristina Hernández, Beatriz Jimenez, Macarena Vargas, Guillermo Ruiz

# %%
import pyomo.environ as pe
import pyomo.opt as po
from pyomo.environ import NonNegativeReals, Binary

# %% [markdown]
# #### Create the model

# %%
model = pe.ConcreteModel()

# %% [markdown]
# ### Sets
#
# * **$D$**: The set of days in the weekly horizon.
#   $$D = \{\text{Monday, Tuesday, Wednesday, Thursday, Friday, Saturday, Sunday}\}$$
# * **$P$**: The set of daily shifts or periods.
#   $$P = \{\text{Morning, Afternoon}\}$$
# * **$H_p$**: The set of hourly time slots available within each period $p \in P$.
#   $$H_p = \{1, 2, 3, 4, 5\}$$
# * **$A$**: The set of community activities to be scheduled.
#   $$A = \{\text{Yoga, CommunityMeeting, KidsClass, CraftsWorkshop}\}$$
# * **$S$**: The set of available supervisors.
#   $$S = \{\text{Sup1, Sup2}\}$$
# * **$\Omega$ (Spatio-temporal Space)**: The complete set of all possible time-indexed combinations, defined as the Cartesian product:
#   $$\Omega = \{(d, p, h) \mid d \in D, p \in P, h \in H_p\}$$

# %%
DAYS = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
PERIODS = ["Morning", "Afternoon"]
ACTIVITIES = ["Yoga", "CommunityMeeting", "KidsClass", "CraftsWorkshop"]
SUPERVISORS = ["Supervisor1", "Supervisor2"]

# Time slots per period (Shift hours)
HM = [1, 2, 3, 4, 5]  # Morning hours
HA = [1, 2, 3, 4, 5]  # Afternoon hours

# These sets allow the model to iterate over days, activities, and personnel
model.d = pe.Set(initialize=DAYS, doc='Days of the week')
model.p = pe.Set(initialize=PERIODS, doc='Day periods (Morning/Afternoon)')
model.a = pe.Set(initialize=ACTIVITIES, doc='Types of activities')
model.s = pe.Set(initialize=SUPERVISORS, doc='Available personnel')


# Defining the hours belonging to each shift
model.Hm = pe.Set(initialize=HM)
model.Ha = pe.Set(initialize=HA)

# Initialization function to automatically assign hourly blocks based on the Period (p)
def H_init(m, p):
    return HM if p == "Morning" else HA

# model.H is an indexed set: model.H['Morning'] will contain [1,2,3,4,5]
model.H = pe.Set(model.p, initialize=H_init, doc='Available hours per period')  


# 'dph' creates the "empty calendar" by combining (Day, Period, Hour)
# This generates the decision space where activities will be assigned.
model.dph = pe.Set(
    dimen=3,
    initialize=[(d, p, h) for d in DAYS for p in PERIODS for h in (HM if p=="Morning" else HA)],
    doc='Full spatio-temporal horizon of the model'
)
# Out:
# WARNING: Implicitly replacing the Component attribute d (type=<class
# 'pyomo.core.base.set.OrderedScalarSet'>) on block unknown with a new Component
# (type=<class 'pyomo.core.base.set.AbstractOrderedScalarSet'>). This is usually
# indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# WARNING: Implicitly replacing the Component attribute p (type=<class
# 'pyomo.core.base.set.OrderedScalarSet'>) on block unknown with a new Component
# (type=<class 'pyomo.core.base.set.AbstractOrderedScalarSet'>). This is usually
# indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# WARNING: Implicitly replacing the Component attribute a (type=<class
# 'pyomo.core.base.set.OrderedScalarSet'>) on block unknown with a new Component
# (type=<class 'pyomo.core.base.set.AbstractOrderedScalarSet'>). This is usually
# indicative of a modelling error. To avoid this warning, use
# ...

# %% [markdown]
# #### Parameters
#
#
# * **$RA_{d,p,h}$**: Venue availability on day $d$, period $p$, and hour $h$ ($1$ if available, $0$ otherwise).
# * **$S_{min,a} \ / \ S_{max,a}$**: Minimum and maximum number of weekly sessions permitted for activity $a$.
# * **$Dur_a$**: Duration of activity $a$, measured in consecutive hourly blocks.
# * **$NS_a$**: Supervisor requirement for activity $a$ (minimum number of staff required).
# * **$SA_{s,d,p,h}$**: Availability of supervisor $s$ at time slot $(d,p,h)$ ($1$ if available, $0$ otherwise).
# * **$Cap$**: Maximum room capacity (occupancy limit).
# * **$D_{a,d,p,h}$**: Estimated demand (number of neighbors) for activity $a$ at time slot $(d,p,h)$.

# %%
# Initialize the venue as available for all time slots in the calendar
room_avail = {(d,p,h): 1 for d in DAYS for p in PERIODS for h in (HM if p=="Morning" else HA)}
model.room_avail = pe.Param(
    model.dph,
    initialize=lambda m,d,p,h: room_avail[(d,p,h)],
    within=pe.Binary,
    doc='Binary parameter for venue open/closed status'
)



# Minimum weekly sessions per activity 
# Every activity must be scheduled at least once per week to ensure variety
min_sessions = {a: 1 for a in ACTIVITIES} 

model.min_sessions = pe.Param(
    model.a,
    initialize=lambda m,a: min_sessions[a],
    within=pe.NonNegativeIntegers,
    doc='Lower bound for weekly activity frequency'
)

# Maximum weekly sessions per activity
# Limits frequency to 5 sessions to prevent activity monopoly
max_sessions = {a: 5 for a in ACTIVITIES} 
model.max_sessions = pe.Param(
    model.a,
    initialize=lambda m,a: max_sessions[a],
    within=pe.NonNegativeIntegers,
    doc='Upper bound for weekly activity frequency'
)

# Activity duration in consecutive hourly blocks
dur = {
    "Yoga": 2,
    "CommunityMeeting": 1,
    "KidsClass": 2,
    "CraftsWorkshop": 1
}

model.dur = pe.Param(
    model.a,
    initialize=lambda m, a: dur[a],
    within=pe.PositiveIntegers,
    doc='Required consecutive hours per session'
)


# 1 if activity requires a supervisor, 0 otherwise

needs_sup = {a: 1 for a in ACTIVITIES} # Default: all activities require supervision
model.needs_sup = pe.Param(
    model.a,
    initialize=lambda m,a: needs_sup[a],
    within=pe.Binary,
    doc='Mandatory supervision flag'
)

# Staff Availability Profile
# Simulation: Supervisors are unavailable on Sunday afternoons for rest periods
sup_avail = {
    (s, d, p, h): 0 if (d == "Sunday" and p == "Afternoon") else 1
    for s in SUPERVISORS
    for d, p, h in model.dph
}

model.sup_avail = pe.Param(
    model.s, model.dph,
    initialize=lambda m, s, d, p, h: sup_avail[(s, d, p, h)],
    within=pe.Binary,
    doc='Staff availability constraints'
)


# Maximum occupancy limit for the venue
CAPACITY_VALUE = 25  
model.capacity = pe.Param(
    initialize=CAPACITY_VALUE,
    within=pe.PositiveIntegers,
    doc='Physical room capacity limit'
)

# Market Demand Estimation by activity type and time slot
# Provides the social basis for the objective function
demand = {
    (a, d, p, h): 15 if a == "Yoga" 
    else 20 if a == "KidsClass" 
    else 10
    for a in ACTIVITIES
    for d, p, h in model.dph
}

model.demand = pe.Param(
    model.a, model.dph,
    initialize=lambda m,a,d,p,h: demand[(a,d,p,h)],
    within=pe.NonNegativeIntegers,
    doc='Estimated community interest per session'
)

# %% [markdown]
# ### Variables
# * $X_{a,d,p,h} \in \{0, 1\}$: Binary variable that equals 1 if activity $a$ starts on day $d$, period $p$, and time slot $h$; 0 otherwise.
# * $n_{a,d,p,h} \in \mathbb{Z}^+$: Integer variable representing the number of attendees for activity $a$ starting at $(d,p,h)$.
# * $y_{a,d,p,h,s} \in \{0, 1\}$: Binary variable that equals 1 if supervisor $s$ is assigned to activity $a$ starting at $(d,p,h)$; 0 otherwise.
# * $R_{a,d,p,h} \in \{0, 1\}$: Binary "Running" variable that equals 1 if activity $a$ is active (occupying the room) at $(d,p,h)$, regardless of when it started.
# * $Z_{min} \in \mathbb{Z}^+$: Auxiliary variable used for multi-criteria analysis, representing the minimum number of attendees across all scheduled sessions.

# %%
# binary (1 if activity a starts on day d at period p time h else 0)
model.X = pe.Var(model.a, model.dph, within=pe.Binary)

# number of attendees of activity a that starts on day d at period d at time slot h
model.n = pe.Var(model.a, model.dph, within=pe.NonNegativeIntegers)

# binary (1 if supervisor s is assigned to activity a at d,p,h)
model.y = pe.Var(model.a, model.dph, model.s, within=pe.Binary)

# auxiliary variable (minimum number of persons among all sessions)
model.Z = pe.Var(within=pe.NonNegativeIntegers)

# binary (1 if activity a is running on day d at period p time h else 0)
model.R = pe.Var(model.a, model.dph, within=pe.Binary)

# %% [markdown]
# ### Objective Function
#  1. Max-Min Fairness: First we want to maximize the attendance of the least popular session. By maximizing the variable Z, we are forcing the model to create a schedule where every activity, even the less popular ones, reaches a respectable level of participation.
#
# $$\max Z$$

# %%
def obj_rule(m):
    return m.Z

model.obj = pe.Objective(rule=obj_rule, sense=pe.maximize)

# %% [markdown]
# 2. Total Attendance Efficiency: After finding the optimal fairness value Z, the first objective is deactivated, and the second is activated. The model will now maximize the total number of neighbors that come to all sessions, always within the constraints established by the first step.
#
#
# $$\max \sum_{a \in A} \sum_{(d,p,h) \in \Omega} n_{a,d,p,h}$$

# %%
# second objective function (for max(min))

def total_attendees_rule(m):
    return sum(m.n[a,(d,p,h)] for a in m.a for (d,p,h) in m.dph)

model.obj_total = pe.Objective(rule=total_attendees_rule, sense=pe.maximize)
model.obj_total.deactivate()

# %% [markdown]
# ### Constraints

# %% [markdown]
#  1. Valid start time: Ckecls if an activity is allowed to start if the current hour plus the duration doesn't go past the limit.
#
# $$h + Dur_{a} - 1 \leq \max(H_{p}) \quad \forall a \in A, p \in P, h \in H_{p}$$

# %%
# valid start time slots
def valid_start(m, a, p, h):
    return h + pe.value(m.dur[a]) - 1 <= max(m.H[p])

# %% [markdown]
#  2. Invalid Start Prohibition
# To ensure the integrity of the schedule, we explicitly forbid starting an activity in a slot that does not allow for its full completion within the same period:
#
# $$X_{a,d,p,h} = 0 \quad \forall (a,d,p,h) \notin \text{ValidStarts}$$

# %%
# invalid starts forced to zero
def invalid_start_rule(m, a, d, p, h):
    if valid_start(m,a,p,h):
        return pe.Constraint.Skip
    return m.X[a,(d,p,h)] == 0

model.invalid_start = pe.Constraint(model.a, model.dph, rule=invalid_start_rule)

# %% [markdown]
#  3. Activity Running Link: This constraint links the start variable $X$ with the state variable $R$. It ensures that if an activity $a$ starts at time $t$, it continues to occupy the room for its entire duration $Dur_a$.
#
# $$R_{a,d,p,h} = \sum_{t \in H_p : t \leq h \leq t + Dur_a - 1} X_{a,d,p,t} \quad \forall a \in A, (d,p,h) \in \Omega$$

# %%
# activity running definition
def running_link_rule(m, a, d, p, h):
    return m.R[a,(d,p,h)] == sum(
        m.X[a,(d,p,t)]
        for t in m.H[p]
        if valid_start(m,a,p,t) and t <= h <= t + pe.value(m.dur[a]) - 1
    )

model.running_link = pe.Constraint(model.a, model.dph, rule=running_link_rule)

# %% [markdown]
# 4. Physical Non-Overlap: Ensures the room is not double-booked.
#    $$\sum_{a \in A} R_{a,d,p,h} \leq 1$$

# %%
# no overlapping activities
def no_overlap_rule(m, d, p, h):
    return sum(m.R[a,(d,p,h)] for a in m.a) <= 1

model.no_overlap = pe.Constraint(model.dph, rule=no_overlap_rule)

# %% [markdown]
# 5. Room Availability: Ensures activities only occur during official opening hours defined by $RA_{d,p,h}$.
#    $$\sum_{a \in A} R_{a,d,p,h} \leq RA_{d,p,h}$$
# If $RA_{d,p,h} = 1$, only one activity can be active. If $RA_{d,p,h} = 0$, no activities are allowed.

# %%
# room availability
def room_availability_rule(m, d, p, h):
    return sum(m.R[a,(d,p,h)] for a in m.a) <= m.room_avail[d,p,h]

model.room_availability = pe.Constraint(model.dph, rule=room_availability_rule)

# %% [markdown]
# 6.  Mandatory Supervision Requirement: This constraint enforces that any activity that begins ($X_{a,d,p,h}=1$) must have the required number of supervisors assigned to it:
#
# $$\sum_{s \in S} y_{a,d,p,h,s} \geq NS_{a} \cdot X_{a,d,p,h} \quad \forall a, d, p, h$$

# %%
# supervisor required
def supervisor_required_rule(m, a, d, p, h):
    return sum(m.y[a,(d,p,h),s] for s in m.s) >= m.needs_sup[a] * m.X[a,(d,p,h)]

model.supervisor_required = pe.Constraint(model.a, model.dph, rule=supervisor_required_rule)

# %% [markdown]
# 7. Supervisor Availability for Full Duration
# To ensure continuous supervision, this constraint links the assignment variable $y$ to the availability parameter $SA$ for every hour $k$ of the activity's duration:
#
# $$y_{a,d,p,h,s} \leq SA_{s,d,p,k} \quad \forall k \in [h, h + Dur_a - 1]$$
#
# If the supervisor is unavailable at any time $k$ during the session, they cannot be assigned to that specific start time.

# %%
# supervisor availability for full duration
model.sup_avail_full = pe.ConstraintList()

for a in model.a:
    for (d,p,h) in model.dph:
        if not valid_start(model,a,p,h):
            continue
        dur_a = int(pe.value(model.dur[a]))
        for s in model.s:
            for k in range(h, h + dur_a):
                model.sup_avail_full.add(
                    model.y[a,(d,p,h),s] <= model.sup_avail[s,d,p,k]
                )

# %% [markdown]
#  8. Supervisor Non-Overlapping: Prevents the double-booking of staff members. It ensures that for any given hour $h$, a supervisor $s$ is assigned to at most one active session:
#
# $$\sum_{a \in A} \sum_{t : t \leq h \leq t + Dur_a - 1} y_{a,d,p,t,s} \leq 1 \quad \forall s, d, p, h$$

# %%
# supervisor no overlap
def supervisor_no_overlap_rule(m, s, d, p, h):
    return sum(
        m.y[a,(d,p,t),s]
        for a in m.a
        for t in m.H[p]
        if valid_start(m,a,p,t) and t <= h <= t + pe.value(m.dur[a]) - 1
    ) <= 1

model.supervisor_no_overlap = pe.Constraint(model.s, model.dph, rule=supervisor_no_overlap_rule)

# %% [markdown]
# 9. Room Capacity: Restricts the number of attendees $n$ by the venue's capacity $K$, and ensures that attendance is only possible if the activity $a$ actually starts ($X=1$):
#
# $$n_{a,d,p,h} \leq K \cdot X_{a,d,p,h} \quad \forall a, d, p, h$$
#
# If $X_{a,d,p,h} = 0$, then $n_{a,d,p,h}$ is forced to 0.

# %%
# capacity constraint
def capacity_rule(m, a, d, p, h):
    return m.n[a,(d,p,h)] <= m.capacity * m.X[a,(d,p,h)]

model.capacity_constraint = pe.Constraint(model.a, model.dph, rule=capacity_rule)

# %% [markdown]
#  10. Demand Limitation: Ensures that the number of attendees $n$ does not exceed the estimated demand $D$ for a specific activity and time slot:
#
# $$n_{a,d,p,h} \leq D_{a,d,p,h} \cdot X_{a,d,p,h} \quad \forall a, d, p, h$$

# %%
# demand constraint
def demand_rule(m, a, d, p, h):
    return m.n[a,(d,p,h)] <= m.demand[a,d,p,h] * m.X[a,(d,p,h)]

model.demand_constraint = pe.Constraint(model.a, model.dph, rule=demand_rule)
# Out:
# WARNING: Implicitly replacing the Component attribute demand_constraint
# (type=<class 'pyomo.core.base.constraint.IndexedConstraint'>) on block unknown
# with a new Component (type=<class
# 'pyomo.core.base.constraint.IndexedConstraint'>). This is usually indicative
# of a modelling error. To avoid this warning, use block.del_component() and
# block.add_component().

# %% [markdown]
# 11. Minimum sessions: Forces the total number of sessions for each activity to meet a minimum threshold:
#
# $$\sum_{(d,p,h) \in \Omega_{valid}} X_{a,d,p,h} \geq S_{min,a} \quad \forall a \in A$$

# %%
# minimum weekly sessions per activity
def min_sessions_rule(m, a):
    return sum(
        m.X[a,(d,p,h)]
        for (d,p,h) in m.dph
        if valid_start(m,a,p,h)
    ) >= m.min_sessions[a]

model.min_sessions_constraint = pe.Constraint(model.a, rule=min_sessions_rule)

# %% [markdown]
# 12. Maximum sessions: Limits the total number of sessions $X$ for each activity $a$ to a maximum threshold :
#
# $$\sum_{(d,p,h) \in \Omega_{valid}} X_{a,d,p,h} \leq S_{max,a} \quad \forall a \in A$$

# %%
# maximum weekly sessions per activity
def max_sessions_rule(m, a):
    return sum(
        m.X[a,(d,p,h)]
        for (d,p,h) in m.dph
        if valid_start(m,a,p,h)
    ) <= m.max_sessions[a]

model.max_sessions_constraint = pe.Constraint(model.a, rule=max_sessions_rule)

# %% [markdown]
# 13. Fairness Logic (Min-Max): To promote a balanced schedule, we define an auxiliary variable $Z$ that tracks the minimum attendance of any scheduled session using a Big-M formulation:
#
# $$Z \leq n_{a,d,p,h} + M(1 - X_{a,d,p,h}) \quad \forall a, d, p, h$$
#
# When $X=1$, $Z$ is bounded by the attendance $n$. When $X=0$, the constraint is relaxed. Maximizing $Z$ in the objective function ensures that even the least-attended session is optimized.

# %%
# z definition
M = CAPACITY_VALUE

def z_rule(m, a, d, p, h):
    return m.Z <= m.n[a,(d,p,h)] + M * (1 - m.X[a,(d,p,h)])

model.z_constraint = pe.Constraint(model.a, model.dph, rule=z_rule)

# %% [markdown]
# #### Solve model

# %%
solver = pe.SolverFactory('gurobi')

#first objective function
results_1 = solver.solve(model, tee=True)

print("===1===")
print("Solver Status:", results_1.solver.status)
print("Termination Condition:", results_1.solver.termination_condition)

z_star = pe.value(model.Z)

# second objetive function

model.obj.deactivate()
model.obj_total.activate()

results_2 = solver.solve(model, tee=True)

print("\n\n===2==")
print("Solver Status:", results_2.solver.status)
print("Termination Condition:", results_2.solver.termination_condition)
# Out:
# WARNING: Could not locate the 'gurobi' executable, which is required for
# solver gurobi
# ---------------------------------------------------------------------------
# ApplicationError                          Traceback (most recent call last)
# Cell In[24], line 2
#       1 solver = pe.SolverFactory('gurobi')
# ----> 2 results = solver.solve(model, tee=True)
#       4 # Mostrar estado de la optimización
#       5 print("Solver Status:", results.solver.status)
#
# File c:\Users\macar\anaconda3\envs\optimizacion\lib\site-packages\pyomo\opt\base\solvers.py:560, in OptSolver.solve(self, *args, **kwds)
#     557 def solve(self, *args, **kwds):
#     558     """Solve the problem"""
# --> 560     self.available(exception_flag=True)
#     561     #
#     562     # If the inputs are models, then validate that they have been
#     563     # constructed! Collect suffix names to try and import from solution.
#     564     #
#     565     from pyomo.core.base.block import BlockData
#
# ...

# %%
## first objective function
print("First objective function")
print("Z = optimum minimum =", z_star)
total_1 = sum(pe.value(model.n[a,(d,p,h)]) for a in model.a for (d,p,h) in model.dph)
print("Total people assisting  =", total_1)

## second objective function
print("\nSecond objective function")
print("Z =", pe.value(model.Z))
print("Total people asisting =", sum(pe.value(model.n[a,(d,p,h)]) for a in model.a for (d,p,h) in model.dph))
# Out:
# solution
# Tuesday Afternoon 1 Yoga attendees 15 supervisors ['Supervisor1']
# Wednesday Morning 4 KidsClass attendees 20 supervisors ['Supervisor1']
# Friday Afternoon 3 CraftsWorkshop attendees 10 supervisors ['Supervisor1', 'Supervisor2']
# Sunday Morning 4 CommunityMeeting attendees 10 supervisors ['Supervisor2']
# z value 10

# %%
print(f"{'DAY':<12} | {'PERIOD':<10} | {'HOUR':<6} | {'ACTIVITY':<18} | {'ATTENDEES':<10} | {'SUPERVISOR'}")
print("-" * 85)

# We iterate through the time horizon and activities
for d in model.d:
    for p in model.p:
        for h in model.H[p]:
            for a in model.a:
                # We check the 'X' variable (Start Indicator)
                if pe.value(model.X[a, (d, p, h)]) > 0.5:
                    
                    # Find which supervisor was assigned to this specific session
                    assigned_sups = [s for s in model.s if pe.value(model.y[a, (d, p, h), s]) > 0.5]
                    sup_name = ", ".join(assigned_sups)
                    
                    # Get the number of attendees
                    attendance = int(pe.value(model.n[a, (d, p, h)]))
                    
                    print(f"{d:<12} | {p:<10} | {h:<6} | {a:<18} | {attendance:<10} | {sup_name}")
